# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import os
import glob

# %%
# files = glob.glob("*.csv")
df_list = pd.DataFrame()
data = pd.read_csv('csv_list/물품 계약 상세내역_2013년01월.csv', encoding='EUC-KR', low_memory=False)

# %%
data.drop('등록유형',axis=1)
# Out:
#        조달구분  공고시스템명   계약구분         계약번호  계약변경차수  물품순번 최종계약여부  \
# 0      중앙조달     NaN  제3자단가      1251297       0     1      N
# 1      중앙조달     NaN  제3자단가      1251297       0     2      N
# 2      중앙조달     NaN  제3자단가      1251297       0     3      N
# 3      중앙조달     NaN  제3자단가      1251297       0     4      N
# 4      중앙조달     NaN  제3자단가      1251297       0     5      N
# ...     ...     ...    ...          ...     ...   ...    ...
# 54480  자체조달     NaN   총액계약  20130135490       0     1      Y
# 54481  자체조달     NaN   총액계약  20130135618       0     1      Y
# 54482  자체조달     NaN   총액계약  20130135656       0     1      Y
# 54483  자체조달     NaN   총액계약  20130135682       0     1      Y
# 54484  자체조달     NaN   총액계약  20130135771       0     1      Y
#
#                      수요기관명   수요기관코드 수요기관구분  ...        납품기한            업체명  \
# 0                   각 수요기관  ZZ99999   기타기관  ...         NaN          선경버티칼
# 1                   각 수요기관  ZZ99999   기타기관  ...         NaN          선경버티칼
# ...

# %%
data.head(10)
# Out:
#         등록유형  조달구분  공고시스템명   계약구분     계약번호  계약변경차수  물품순번 최종계약여부   수요기관명  \
# 0  나라장터(G2B)  중앙조달     NaN  제3자단가  1251297       0     1      N  각 수요기관
# 1  나라장터(G2B)  중앙조달     NaN  제3자단가  1251297       0     2      N  각 수요기관
# 2  나라장터(G2B)  중앙조달     NaN  제3자단가  1251297       0     3      N  각 수요기관
# 3  나라장터(G2B)  중앙조달     NaN  제3자단가  1251297       0     4      N  각 수요기관
# 4  나라장터(G2B)  중앙조달     NaN  제3자단가  1251297       0     5      N  각 수요기관
# 5  나라장터(G2B)  중앙조달     NaN  제3자단가  1251297       0     6      N  각 수요기관
# 6  나라장터(G2B)  중앙조달     NaN  제3자단가  1251297       0     7      N  각 수요기관
# 7  나라장터(G2B)  중앙조달     NaN  제3자단가  1251297       0     8      N  각 수요기관
# 8  나라장터(G2B)  중앙조달     NaN  제3자단가  1261574       0     1      Y  각 수요기관
# 9  나라장터(G2B)  중앙조달     NaN  제3자단가  1261574       0     2      Y  각 수요기관
#
#     수요기관코드  ... 납품기한         업체명 업체기업구분명 조달요청번호       입찰공고번호 입찰공고차수  \
# 0  ZZ99999  ...  NaN       선경버티칼    중소기업    NaN  20121019960    0.0
# ...
