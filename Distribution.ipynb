# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import os
import glob

# %%
# files = glob.glob("*.csv")
df_list = pd.DataFrame()
data = pd.read_csv('concat_list_1301-1912.csv', encoding='UTF-8', low_memory=False)

# %%
# df_list.drop(labels='납품기한',axis=1)
# df_list.drop(columns="공고시스템명")
# data.drop('Unnamed: 0',axis=1).to_csv("concat_list_1301-1912_2.csv")

# %%
# data2 = data.drop(labels=['Unnamed: 0','계약구분','수요기관지역명','수요기관코드','계약법구분','조항호코드','조항호명','계약방법','다수공급자계약여부','우수제품여부','중소기업자간경쟁제품여부','공사용자재직접구매대상여부','단위','조달요청번호','입찰계약방법','낙찰자결정방법','장기계약차수','장기계속계약여부'],errors='ignore')

# %%
data.drop(columns=['Unnamed: 0.1','Unnamed: 0','계약구분','수요기관지역명','수요기관코드','계약법구분','조항호코드','조항호명','계약방법',
                   '다수공급자계약여부','우수제품여부','중소기업자간경쟁제품여부','공사용자재직접구매대상여부','단위','조달요청번호','입찰계약방법',
                   '낙찰자결정방법','장기계약차수','장기계속계약여부',
                   '공고시스템명','납품기한','물품순번','계약변경차수','입찰공고번호','입찰공고차수'],inplace=True,errors='ignore')

# %%
# 데이터 저장
data.to_csv("concat_list_1301-1912_2.csv")

# %%
data.loc[0]
# Out:
# 등록유형                                          나라장터(G2B)
# 조달구분                                               중앙조달
# 계약번호                                          001881066
# 최종계약여부                                                Y
# 수요기관명                                            각 수요기관
# 수요기관구분                                             기타기관
# 계약건명                                            태양광발전장치
# 물품분류번호                                       26111607.0
# 품명                                              태양광발전장치
# 세부물품분류번호                                   2611160701.0
# 세부품명                                            태양광발전장치
# 물품식별번호                                       22319650.0
# 품목          태양광발전장치, (부품)에스이앤지, SENG-20ST, 20kW용, H형지지대
# 최초계약일자                                       20180508.0
# 계약일자                                           20190830
# 단가                                            1400000.0
# 수량                                                 33.0
# 금액                                           46200000.0
# 증감수량                                                3.0
# 증감금액                                          4200000.0
# 계약수량                                              792.0
# 계약금액                                      15166767000.0
# 업체명                                          주식회사 에스이앤지
# 업체기업구분명                                            중소기업
# Name: 0, dtype: object

# %%
assignType = data['등록유형']

# %%
# 등록 유형 나라장터만 남기기
# 중복 제거
assignType.drop_duplicates()
# Out:
# 0         나라장터(G2B)
# 129103    자체전자조달시스템
# Name: 등록유형, dtype: object

# %%
filterAssign = data[data['등록유형'].str.contains('자체전자조달시스템')].index
data.drop(filterAssign,inplace=True)

# %%
data.head(10)
# Out:
#         등록유형  조달구분       계약번호 최종계약여부   수요기관명 수요기관구분     계약건명      물품분류번호  \
# 0  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 1  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 2  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 3  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 4  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 5  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 6  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 7  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 8  나라장터(G2B)  중앙조달  001881066      Y  각 수요기관   기타기관  태양광발전장치  26111607.0
# 9  나라장터(G2B)  중앙조달  001930017      Y  각 수요기관   기타기관      분전반  39121101.0
#
#         품명      세부물품분류번호  ...      계약일자         단가     수량           금액  증감수량  \
# 0  태양광발전장치  2.611161e+09  ...  20190830  1400000.0   33.0   46200000.0   3.0
# 1  태양광발전장치  2.611161e+09  ...  20190830  3250000.0   33.0  107250000.0   3.0
# 2  태양광발전장치  2.611161e+09  ...  20190830  3630000.0   33.0  119790000.0   3.0
# 3  태양광발전장치  2.611161e+09  ...  20190830  3690000.0   33.0  121770000.0   3.0
# 4  태양광발전장치  2.611161e+09  ...  20190830  4290000.0   33.0  141570000.0   3.0
# 5  태양광발전장치  2.611161e+09  ...  20190830  4440000.0   33.0  146520000.0   3.0
# 6  태양광발전장치  2.611161e+09  ...  20190830  7000000.0   33.0  231000000.0   3.0
# 7  태양광발전장치  2.611161e+09  ...  20190830  2000000.0   33.0   66000000.0   3.0
# 8  태양광발전장치  2.611161e+09  ...  20190830  7000000.0   33.0  231000000.0   3.0
# 9      분전반  3.912110e+09  ...  20190830  1466890.0  500.0  733445000.0   0.0
#
#          증감금액   계약수량          계약금액         업체명  업체기업구분명
# 0   4200000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 1   9750000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 2  10890000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 3  11070000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 4  12870000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 5  13320000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 6  21000000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 7   6000000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 8  21000000.0  792.0  1.516677e+10  주식회사 에스이앤지     중소기업
# 9         0.0  500.0  7.334450e+08   주식회사 태영산전     중소기업
#
# [10 rows x 24 columns]

# %%
# 품목 중복 제거
# data.drop_duplicates(['품목'], )
# Out:
#               등록유형  조달구분         계약번호 최종계약여부           수요기관명 수요기관구분  \
# 0        나라장터(G2B)  중앙조달    001881066      Y          각 수요기관   기타기관
# 1        나라장터(G2B)  중앙조달    001881066      Y          각 수요기관   기타기관
# 2        나라장터(G2B)  중앙조달    001881066      Y          각 수요기관   기타기관
# 3        나라장터(G2B)  중앙조달    001881066      Y          각 수요기관   기타기관
# 4        나라장터(G2B)  중앙조달    001881066      Y          각 수요기관   기타기관
# ...            ...   ...          ...    ...             ...    ...
# 9645452  나라장터(G2B)  자체조달  20150948502      Y       서울특별시 구로구    지자체
# 9645509  나라장터(G2B)  자체조달  20150948795      Y  전라남도교육청 순천고등학교   교육기관
# 9645607  나라장터(G2B)  자체조달  20150949474      Y  강원도 평창군 농업기술센터    지자체
# 9645620  나라장터(G2B)  자체조달  20150949560      Y       서울특별시 송파구    지자체
# 9645707  나라장터(G2B)  자체조달  20150950338      Y       서울특별시 구로구    지자체
#
#                                   계약건명      물품분류번호        품명      세부물품분류번호  \
# 0                              태양광발전장치  26111607.0   태양광발전장치  2.611161e+09
# 1                              태양광발전장치  26111607.0   태양광발전장치  2.611161e+09
# 2                              태양광발전장치  26111607.0   태양광발전장치  2.611161e+09
# 3                              태양광발전장치  26111607.0   태양광발전장치  2.611161e+09
# 4                              태양광발전장치  26111607.0   태양광발전장치  2.611161e+09
# ...                                ...         ...       ...           ...
# 9645452                 신도림간이수문 제작구매설치    40141784        수문  4.014178e+09
# 9645509       순천고등학교 과학교구(용존산소량측정기) 구입    41115611  용존산소량측정기  4.111561e+09
# 9645607  2015년 수산종묘 매입방류사업 종묘(대농갱이) 구입    50121598    수산물가공품  5.012160e+09
# 9645620          홈페이지서버메모리 및 스토리지 증설사업    43201402   메모리모듈카드  4.320140e+09
# 9645707         개봉1빗물펌프장 옥상계단외 2건 제작설치    30161908      계단부품  3.016191e+09
#
#          ...      계약일자           단가       수량           금액     증감수량  \
# 0        ...  20190830   1400000.00     33.0   46200000.0      3.0
# 1        ...  20190830   3250000.00     33.0  107250000.0      3.0
# 2        ...  20190830   3630000.00     33.0  119790000.0      3.0
# 3        ...  20190830   3690000.00     33.0  121770000.0      3.0
# 4        ...  20190830   4290000.00     33.0  141570000.0      3.0
# ...      ...       ...          ...      ...          ...      ...
# 9645452  ...  20150930  17857000.00      1.0   17857000.0      1.0
# 9645509  ...  20150930   1500000.00      1.0    1500000.0      1.0
# 9645607  ...  20150930       250.00  77760.0   19440000.0  77760.0
# 9645620  ...  20150930    931764.71     17.0   15840000.0     17.0
# 9645707  ...  20150930   4220500.00      1.0    4220500.0      1.0
#
#                증감금액     계약수량          계약금액          업체명  업체기업구분명
# 0         4200000.0    792.0  1.516677e+10   주식회사 에스이앤지     중소기업
# 1         9750000.0    792.0  1.516677e+10   주식회사 에스이앤지     중소기업
# 2        10890000.0    792.0  1.516677e+10   주식회사 에스이앤지     중소기업
# 3        11070000.0    792.0  1.516677e+10   주식회사 에스이앤지     중소기업
# 4        12870000.0    792.0  1.516677e+10   주식회사 에스이앤지     중소기업
# ...             ...      ...           ...          ...      ...
# 9645452  17857000.0      1.0  1.785700e+07      우일산업(주)     중소기업
# 9645509   1500000.0      1.0  1.500000e+06  세창인스트루먼트(주)     중소기업
# 9645607  19440000.0  77760.0  1.944000e+07         화성수산     중소기업
# 9645620  15840000.0     17.0  1.584000e+07     (주)네컴시스템     중소기업
# 9645707   4220500.0      3.0  5.997000e+06       동국하이테크     중소기업
#
# [1047075 rows x 24 columns]

# %%
# 품명 리스트 생성
# 중복 제거
productList = data['품명']

# %%
productList.drop_duplicates(inplace=True)

# %%
productList.to_csv("productList.csv")

# %%
# 세부품목 리스트 생성
# 중복 제거
detailproductList = data['세부품명']

# %%
detailproductList.drop_duplicates(inplace=True)

# %%
detailproductList.to_csv("detailproductList.csv")

# %%
detailproductList
# Out:
# 0            태양광발전장치
# 9                분전반
# 10         엑스레이화물검색기
# 11            도막형바닥재
# 15               제진기
#              ...
# 9571695       기도압감시기
# 9578366      테이퍼링게이지
# 9597529     외과봉합용유지대
# 9605733      구두창그라인더
# 9633052    콘크리트바닥강화제
# Name: 세부품명, Length: 10260, dtype: object

# %%
# files = glob.glob("*.csv")
filter_df_list = pd.DataFrame()
filter_list = pd.read_csv('filter.csv', encoding='EUC-KR', low_memory=False)

# %%
filter_list
# Out:
#             세부품명
# 0         자료수집장치
# 1         레이저프린터
# 2         잉크젯프린터
# 3    버스및차량정보안내장치
# 4          공기청정기
# ..           ...
# 113        청소로보트
# 114        프린터서버
# 115        명함스캐너
# 116        기상FAX
# 117   휴대용MP3플레이어
#
# [118 rows x 1 columns]

# %%
# df_dict = df.to_dict()
# dic_val = df_dict['sepal length (cm)'].values()
# dic_list = list(dic_val)

fil2list = filter_list['세부품명'].to_list()


# 데이터프레임 생성
filterDf = pd.DataFrame()

# join함수를 이용하여 이어주고 contains 함수에 넣기
filter2join = '|'.join(fil2list)
result = data[data['세부품명'].str.contains(filter2join)]
# df[df['A'].str.contains("Hello|Britain")==True]
# Out:
# /tmp/ipykernel_323/3446088323.py:13: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   result = data[data['세부품명'].str.contains(filter2join)]

# %%
result
# Out:
#               등록유형  조달구분         계약번호 최종계약여부                    수요기관명  수요기관구분  \
# 1200     나라장터(G2B)  중앙조달    391930302      Y                  제주특별자치도     지자체
# 1242     나라장터(G2B)  중앙조달    001761764      Y                   각 수요기관    기타기관
# 1243     나라장터(G2B)  중앙조달    001761764      Y                   각 수요기관    기타기관
# 1244     나라장터(G2B)  중앙조달    001761764      Y                   각 수요기관    기타기관
# 1245     나라장터(G2B)  중앙조달    001761764      Y                   각 수요기관    기타기관
# ...            ...   ...          ...    ...                      ...     ...
# 9645308  나라장터(G2B)  자체조달  20150947868      Y          강원도 고성군 상하수도사업소     지자체
# 9645484  나라장터(G2B)  자체조달  20150948644      Y                  국방과학연구소  기타공공기관
# 9645550  나라장터(G2B)  자체조달  20150948977      Y                 전라북도 고창군     지자체
# 9645580  나라장터(G2B)  자체조달  20150949209      Y  농림축산식품부 농림축산검역본부 서울지역본부    국가기관
# 9645689  나라장터(G2B)  자체조달  20150950107      Y             서울특별시농수산식품공사   지방공기업
#
#                             계약건명      물품분류번호                  품명  \
# 1200     2019 지하수 이용량 모니터링시스템 구매  43211798.0              자료수집장치
# 1242                      레이저프린터  43212105.0              레이저프린터
# 1243                      레이저프린터  43212105.0              레이저프린터
# 1244                      레이저프린터  43212105.0              레이저프린터
# 1245                      레이저프린터  43212105.0              레이저프린터
# ...                          ...         ...                 ...
# 9645308   거진배수지 CCTV설치공사 관급자재 구입    46171622              영상감시장치
# 9645484     공통지원용 리스 PC 및 프린터 구매    43212110              다기능프린터
# 9645550          다목적용 CCTV 구매 설치    46171622              영상감시장치
# 9645580        식물검역장비(유전자증폭기) 구입    41106307  중합효소연쇄반응(PCR)최적화제품
# 9645689         소방설비 유지보수용 물품 구매    46191501               연기감지기
#
#              세부물품분류번호  ...      계약일자           단가      수량            금액  증감수량  \
# 1200     4.321180e+09  ...  20190830  572000000.0     1.0  5.720000e+08   1.0
# 1242     4.321211e+09  ...  20190829     148500.0   500.0  7.425000e+07   0.0
# 1243     4.321211e+09  ...  20190829     167200.0  2000.0  3.344000e+08   0.0
# 1244     4.321211e+09  ...  20190829     316800.0  5000.0  1.584000e+09   0.0
# 1245     4.321211e+09  ...  20190829     495000.0   300.0  1.485000e+08   0.0
# ...               ...  ...       ...          ...     ...           ...   ...
# 9645308  4.617162e+09  ...  20150930   19090000.0     1.0  1.909000e+07   1.0
# 9645484  4.321211e+09  ...  20150930   89377150.0     1.0  8.937715e+07   1.0
# 9645550  4.617162e+09  ...  20150930    6745000.0     1.0  6.745000e+06   1.0
# 9645580  4.110631e+09  ...  20150930    6600000.0     1.0  6.600000e+06   1.0
# 9645689  4.619150e+09  ...  20150930    5170000.0     1.0  5.170000e+06   1.0
#
#                 증감금액     계약수량          계약금액          업체명  업체기업구분명
# 1200     572000000.0      1.0  5.720000e+08     (주)소다시스템     중소기업
# 1242             0.0  10700.0  3.551350e+09      주식회사 씨윈     중소기업
# 1243             0.0  10700.0  3.551350e+09      주식회사 씨윈     중소기업
# 1244             0.0  10700.0  3.551350e+09      주식회사 씨윈     중소기업
# 1245             0.0  10700.0  3.551350e+09      주식회사 씨윈     중소기업
# ...              ...      ...           ...          ...      ...
# 9645308   19090000.0      1.0  1.909000e+07   믿음이엔지(ENG)     중소기업
# 9645484   89377150.0      1.0  8.937715e+07  태성네트웍스 주식회사     중소기업
# 9645550    6745000.0      1.0  6.745000e+06  유한회사 신도정보통신     중소기업
# 9645580    6600000.0      1.0  6.600000e+06         도우통상     중소기업
# 9645689    5170000.0      1.0  5.170000e+06  주식회사 엠브이피소방     중소기업
#
# [158527 rows x 24 columns]

# %%
result.to_csv("ResultFilter1301-1912.csv")
